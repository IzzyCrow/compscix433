# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import numpy as np
import scipy

# %%
auto = pd.read_csv('auto_mpg.csv')
print(auto.head())
auto_disp = auto['displacement'].astype(float)
auto_mpg = auto['mpg'].astype(float)
mean_disp = np.mean(auto_disp)
min_disp = np.min(auto_disp)
max_disp = np.max(auto_disp)
print(mean_disp, max_disp, min_disp, max_disp-min_disp)
#auto_disp = auto_disp.apply(lambda x: x/100)
print("-----Displacement Stats-----" )
print(auto_disp.describe())
#auto_mpg = auto_mpg.apply(lambda x: x/100)
print("-----Mileage Stats-----" )
print(auto_mpg.describe())
# Out:
#     mpg  cylinder  displacement horse power  weight  acceleration  model year  \
# 0  18.0         8         307.0         130    3504          12.0          70
# 1  15.0         8         350.0         165    3693          11.5          70
# 2  18.0         8         318.0         150    3436          11.0          70
# 3  16.0         8         304.0         150    3433          12.0          70
# 4  17.0         8         302.0         140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
# 193.42587939698493 455.0 68.0 387.0
# -----Displacement Stats-----
# count    398.000000
# mean     193.425879
# std      104.269838
# min       68.000000
# 25%      104.250000
# 50%      148.500000
# 75%      262.000000
# max      455.000000
# Name: displacement, dtype: float64
# -----Mileage Stats-----
# count    398.000000
# mean      23.514573
# std        7.815984
# min        9.000000
# 25%       17.500000
# 50%       23.000000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
print(type(auto_disp))
# Out:
# <class 'pandas.core.series.Series'>

# %%
x_train, x_test, y_train, y_test = train_test_split(auto_disp, \
                                                    auto_mpg, \
                                                    test_size=0.2, \
                                                    random_state=4)

# %%
print(y_train.shape) 
y_train = y_train[:,None]
print(y_train.shape)
x_train = x_train[:,None]
print(x_train.shape)
x_test = x_test[:,None]
y_test = y_test[:,None]
# Out:
# (318,)
# (318, 1)
# (318, 1)

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import numpy as np


km = KMeans(
    n_clusters=6, init='random',
    n_init=10, max_iter=300, 
    tol=1e-04, random_state=0
)
# X = np.array(auto_disp)
X = x_train
y_km = km.fit_predict(X.reshape(-1, 1))

# %%
print(y_km)
# Out:
# [0 4 2 0 2 2 1 2 0 2 0 4 5 4 5 1 4 5 0 5 1 0 4 2 3 3 2 0 2 5 3 5 1 0 0 2 3
#  2 1 5 0 0 3 3 1 5 0 3 3 1 3 1 5 5 1 2 3 0 2 0 3 2 2 3 0 5 5 0 0 5 4 2 0 0
#  2 0 4 2 0 3 2 3 2 1 3 3 2 5 1 1 2 3 3 5 5 2 4 2 1 1 1 3 2 5 0 0 1 5 3 2 2
#  0 2 1 2 0 2 3 2 2 5 1 1 4 0 3 0 3 1 4 2 1 0 3 3 3 5 3 0 1 4 3 2 5 2 0 0 3
#  3 3 2 0 3 5 3 1 5 1 5 1 4 5 0 3 2 0 5 0 5 1 2 1 2 5 1 2 0 0 2 0 1 5 0 2 4
#  2 5 4 5 2 2 3 5 0 2 5 4 3 4 5 3 1 1 3 3 0 5 3 2 5 2 3 2 2 0 0 5 1 5 3 1 1
#  3 2 4 5 0 5 0 0 2 2 2 2 2 0 4 3 3 3 3 5 2 5 2 5 0 5 2 0 2 5 5 2 2 0 2 4 2
#  1 2 2 0 5 3 0 2 2 0 5 5 3 2 2 3 1 4 0 3 5 2 5 0 2 1 2 2 3 5 1 3 0 2 0 3 3
#  3 5 2 0 2 4 0 1 1 2 4 1 1 0 2 1 5 1 2 2 1 3]

# %%
print(X)
# Out:
# [[250. ]
#  [383. ]
#  [ 97. ]
#  [250. ]
#  [ 97. ]
#  [ 79. ]
#  [151. ]
#  [ 97. ]
#  [250. ]
#  [ 89. ]
#  [258. ]
#  [400. ]
#  [350. ]
#  [400. ]
#  [350. ]
#  [144. ]
#  [400. ]
#  [360. ]
#  [225. ]
#  [305. ]
#  [140. ]
#  [225. ]
#  [400. ]
#  [101. ]
#  [120. ]
#  [121. ]
#  [ 91. ]
#  [262. ]
#  [ 98. ]
#  [302. ]
#  [119. ]
#  [318. ]
#  [173. ]
#  [258. ]
#  [200. ]
#  [ 89. ]
#  [107. ]
#  [ 97. ]
#  [156. ]
#  [318. ]
#  [232. ]
#  [225. ]
#  [119. ]
#  [107. ]
#  [168. ]
#  [302. ]
#  [231. ]
#  [122. ]
#  [105. ]
#  [181. ]
#  [121. ]
#  [140. ]
#  [350. ]
#  [351. ]
#  [168. ]
#  [ 85. ]
#  [122. ]
#  [231. ]
#  [ 85. ]
#  [232. ]
#  [105. ]
#  [ 78. ]
#  [ 98. ]
#  [121. ]
#  [200. ]
#  [350. ]
#  [350. ]
#  [199. ]
#  [225. ]
#  [350. ]
#  [400. ]
#  [ 98. ]
#  [250. ]
#  [198. ]
#  [ 85. ]
#  [267. ]
#  [400. ]
#  [ 91. ]
#  [200. ]
#  [108. ]
#  [ 70. ]
#  [110. ]
#  [ 85. ]
#  [156. ]
#  [105. ]
#  [122. ]
#  [ 76. ]
#  [351. ]
#  [163. ]
#  [135. ]
#  [ 97. ]
#  [112. ]
#  [119. ]
#  [350. ]
#  [318. ]
#  [ 90. ]
#  [400. ]
#  [ 97. ]
#  [140. ]
#  [140. ]
#  [155. ]
#  [112. ]
#  [ 90. ]
#  [351. ]
#  [250. ]
#  [250. ]
#  [140. ]
#  [350. ]
#  [115. ]
#  [ 98. ]
#  [ 97. ]
#  [200. ]
#  [ 97. ]
#  [134. ]
#  [ 68. ]
#  [250. ]
#  [ 85. ]
#  [108. ]
#  [ 91. ]
#  [ 90. ]
#  [351. ]
#  [135. ]
#  [151. ]
#  [400. ]
#  [231. ]
#  [122. ]
#  [231. ]
#  [107. ]
#  [135. ]
#  [455. ]
#  [ 70. ]
#  [140. ]
#  [232. ]
#  [108. ]
#  [116. ]
#  [105. ]
#  [302. ]
#  [121. ]
#  [258. ]
#  [140. ]
#  [429. ]
#  [121. ]
#  [ 97. ]
#  [304. ]
#  [ 97. ]
#  [258. ]
#  [250. ]
#  [120. ]
#  [131. ]
#  [120. ]
#  [ 97. ]
#  [225. ]
#  [113. ]
#  [318. ]
#  [120. ]
#  [135. ]
#  [307. ]
#  [151. ]
#  [304. ]
#  [156. ]
#  [400. ]
#  [302. ]
#  [232. ]
#  [121. ]
#  [ 98. ]
#  [231. ]
#  [350. ]
#  [225. ]
#  [350. ]
#  [163. ]
#  [ 79. ]
#  [168. ]
#  [ 98. ]
#  [350. ]
#  [173. ]
#  [ 90. ]
#  [250. ]
#  [260. ]
#  [ 86. ]
#  [225. ]
#  [156. ]
#  [318. ]
#  [250. ]
#  [ 97. ]
#  [429. ]
#  [ 98. ]
#  [350. ]
#  [400. ]
#  [351. ]
#  [ 89. ]
#  [ 85. ]
#  [119. ]
#  [302. ]
#  [200. ]
#  [ 97. ]
#  [318. ]
#  [383. ]
#  [121. ]
#  [440. ]
#  [318. ]
#  [116. ]
#  [134. ]
#  [135. ]
#  [112. ]
#  [112. ]
#  [225. ]
#  [318. ]
#  [105. ]
#  [ 96. ]
#  [350. ]
#  [ 91. ]
#  [114. ]
#  [ 91. ]
#  [ 98. ]
#  [198. ]
#  [232. ]
#  [304. ]
#  [134. ]
#  [318. ]
#  [119. ]
#  [151. ]
#  [140. ]
#  [108. ]
#  [ 70. ]
#  [429. ]
#  [302. ]
#  [232. ]
#  [351. ]
#  [225. ]
#  [225. ]
#  [ 71. ]
#  [ 91. ]
#  [ 97. ]
#  [ 98. ]
#  [ 71. ]
#  [198. ]
#  [390. ]
#  [120. ]
#  [121. ]
#  [113. ]
#  [121. ]
#  [318. ]
#  [ 85. ]
#  [318. ]
#  [ 72. ]
#  [318. ]
#  [262. ]
#  [302. ]
#  [ 79. ]
#  [232. ]
#  [ 97. ]
#  [360. ]
#  [350. ]
#  [ 98. ]
#  [ 91. ]
#  [225. ]
#  [ 98. ]
#  [400. ]
#  [ 91. ]
#  [151. ]
#  [ 98. ]
#  [ 97. ]
#  [200. ]
#  [351. ]
#  [104. ]
#  [260. ]
#  [ 98. ]
#  [ 79. ]
#  [232. ]
#  [305. ]
#  [307. ]
#  [111. ]
#  [ 97. ]
#  [ 83. ]
#  [116. ]
#  [140. ]
#  [455. ]
#  [250. ]
#  [130. ]
#  [304. ]
#  [ 98. ]
#  [318. ]
#  [250. ]
#  [ 80. ]
#  [140. ]
#  [ 79. ]
#  [ 86. ]
#  [122. ]
#  [302. ]
#  [140. ]
#  [120. ]
#  [232. ]
#  [ 91. ]
#  [250. ]
#  [120. ]
#  [107. ]
#  [116. ]
#  [307. ]
#  [ 88. ]
#  [200. ]
#  [ 86. ]
#  [400. ]
#  [231. ]
#  [140. ]
#  [151. ]
#  [ 98. ]
#  [440. ]
#  [140. ]
#  [141. ]
#  [231. ]
#  [ 97.5]
#  [173. ]
#  [350. ]
#  [145. ]
#  [ 91. ]
#  [ 90. ]
#  [171. ]
#  [121. ]]

# %%
for i in zip(y_km, X):
    print(i)
# Out:
# (0, array([250.]))
# (4, array([383.]))
# (2, array([97.]))
# (0, array([250.]))
# (2, array([97.]))
# (2, array([79.]))
# (1, array([151.]))
# (2, array([97.]))
# (0, array([250.]))
# (2, array([89.]))
# (0, array([258.]))
# (4, array([400.]))
# (5, array([350.]))
# (4, array([400.]))
# (5, array([350.]))
# (1, array([144.]))
# (4, array([400.]))
# (5, array([360.]))
# (0, array([225.]))
# (5, array([305.]))
# (1, array([140.]))
# (0, array([225.]))
# (4, array([400.]))
# (2, array([101.]))
# (3, array([120.]))
# (3, array([121.]))
# (2, array([91.]))
# (0, array([262.]))
# (2, array([98.]))
# (5, array([302.]))
# (3, array([119.]))
# (5, array([318.]))
# (1, array([173.]))
# (0, array([258.]))
# (0, array([200.]))
# (2, array([89.]))
# (3, array([107.]))
# (2, array([97.]))
# (1, array([156.]))
# (5, array([318.]))
# (0, array([232.]))
# (0, array([225.]))
# (3, array([119.]))
# (3, array([107.]))
# (1, array([168.]))
# (5, array([302.]))
# (0, array([231.]))
# (3, array([122.]))
# (3, array([105.]))
# (1, array([181.]))
# (3, array([121.]))
# (1, array([140.]))
# (5, array([350.]))
# (5, array([351.]))
# (1, array([168.]))
# (2, array([85.]))
# (3, array([122.]))
# (0, array([231.]))
# (2, array([85.]))
# (0, array([232.]))
# (3, array([105.]))
# (2, array([78.]))
# (2, array([98.]))
# (3, array([121.]))
# (0, array([200.]))
# (5, array([350.]))
# (5, array([350.]))
# (0, array([199.]))
# (0, array([225.]))
# (5, array([350.]))
# (4, array([400.]))
# (2, array([98.]))
# (0, array([250.]))
# (0, array([198.]))
# (2, array([85.]))
# (0, array([267.]))
# (4, array([400.]))
# (2, array([91.]))
# (0, array([200.]))
# (3, array([108.]))
# (2, array([70.]))
# (3, array([110.]))
# (2, array([85.]))
# (1, array([156.]))
# (3, array([105.]))
# (3, array([122.]))
# (2, array([76.]))
# (5, array([351.]))
# (1, array([163.]))
# (1, array([135.]))
# (2, array([97.]))
# (3, array([112.]))
# (3, array([119.]))
# (5, array([350.]))
# (5, array([318.]))
# (2, array([90.]))
# (4, array([400.]))
# (2, array([97.]))
# (1, array([140.]))
# (1, array([140.]))
# (1, array([155.]))
# (3, array([112.]))
# (2, array([90.]))
# (5, array([351.]))
# (0, array([250.]))
# (0, array([250.]))
# (1, array([140.]))
# (5, array([350.]))
# (3, array([115.]))
# (2, array([98.]))
# (2, array([97.]))
# (0, array([200.]))
# (2, array([97.]))
# (1, array([134.]))
# (2, array([68.]))
# (0, array([250.]))
# (2, array([85.]))
# (3, array([108.]))
# (2, array([91.]))
# (2, array([90.]))
# (5, array([351.]))
# (1, array([135.]))
# (1, array([151.]))
# (4, array([400.]))
# (0, array([231.]))
# (3, array([122.]))
# (0, array([231.]))
# (3, array([107.]))
# (1, array([135.]))
# (4, array([455.]))
# (2, array([70.]))
# (1, array([140.]))
# (0, array([232.]))
# (3, array([108.]))
# (3, array([116.]))
# (3, array([105.]))
# (5, array([302.]))
# (3, array([121.]))
# (0, array([258.]))
# (1, array([140.]))
# (4, array([429.]))
# (3, array([121.]))
# (2, array([97.]))
# (5, array([304.]))
# (2, array([97.]))
# (0, array([258.]))
# (0, array([250.]))
# (3, array([120.]))
# (3, array([131.]))
# (3, array([120.]))
# (2, array([97.]))
# (0, array([225.]))
# (3, array([113.]))
# (5, array([318.]))
# (3, array([120.]))
# (1, array([135.]))
# (5, array([307.]))
# (1, array([151.]))
# (5, array([304.]))
# (1, array([156.]))
# (4, array([400.]))
# (5, array([302.]))
# (0, array([232.]))
# (3, array([121.]))
# (2, array([98.]))
# (0, array([231.]))
# (5, array([350.]))
# (0, array([225.]))
# (5, array([350.]))
# (1, array([163.]))
# (2, array([79.]))
# (1, array([168.]))
# (2, array([98.]))
# (5, array([350.]))
# (1, array([173.]))
# (2, array([90.]))
# (0, array([250.]))
# (0, array([260.]))
# (2, array([86.]))
# (0, array([225.]))
# (1, array([156.]))
# (5, array([318.]))
# (0, array([250.]))
# (2, array([97.]))
# (4, array([429.]))
# (2, array([98.]))
# (5, array([350.]))
# (4, array([400.]))
# (5, array([351.]))
# (2, array([89.]))
# (2, array([85.]))
# (3, array([119.]))
# (5, array([302.]))
# (0, array([200.]))
# (2, array([97.]))
# (5, array([318.]))
# (4, array([383.]))
# (3, array([121.]))
# (4, array([440.]))
# (5, array([318.]))
# (3, array([116.]))
# (1, array([134.]))
# (1, array([135.]))
# (3, array([112.]))
# (3, array([112.]))
# (0, array([225.]))
# (5, array([318.]))
# (3, array([105.]))
# (2, array([96.]))
# (5, array([350.]))
# (2, array([91.]))
# (3, array([114.]))
# (2, array([91.]))
# (2, array([98.]))
# (0, array([198.]))
# (0, array([232.]))
# (5, array([304.]))
# (1, array([134.]))
# (5, array([318.]))
# (3, array([119.]))
# (1, array([151.]))
# (1, array([140.]))
# (3, array([108.]))
# (2, array([70.]))
# (4, array([429.]))
# (5, array([302.]))
# (0, array([232.]))
# (5, array([351.]))
# (0, array([225.]))
# (0, array([225.]))
# (2, array([71.]))
# (2, array([91.]))
# (2, array([97.]))
# (2, array([98.]))
# (2, array([71.]))
# (0, array([198.]))
# (4, array([390.]))
# (3, array([120.]))
# (3, array([121.]))
# (3, array([113.]))
# (3, array([121.]))
# (5, array([318.]))
# (2, array([85.]))
# (5, array([318.]))
# (2, array([72.]))
# (5, array([318.]))
# (0, array([262.]))
# (5, array([302.]))
# (2, array([79.]))
# (0, array([232.]))
# (2, array([97.]))
# (5, array([360.]))
# (5, array([350.]))
# (2, array([98.]))
# (2, array([91.]))
# (0, array([225.]))
# (2, array([98.]))
# (4, array([400.]))
# (2, array([91.]))
# (1, array([151.]))
# (2, array([98.]))
# (2, array([97.]))
# (0, array([200.]))
# (5, array([351.]))
# (3, array([104.]))
# (0, array([260.]))
# (2, array([98.]))
# (2, array([79.]))
# (0, array([232.]))
# (5, array([305.]))
# (5, array([307.]))
# (3, array([111.]))
# (2, array([97.]))
# (2, array([83.]))
# (3, array([116.]))
# (1, array([140.]))
# (4, array([455.]))
# (0, array([250.]))
# (3, array([130.]))
# (5, array([304.]))
# (2, array([98.]))
# (5, array([318.]))
# (0, array([250.]))
# (2, array([80.]))
# (1, array([140.]))
# (2, array([79.]))
# (2, array([86.]))
# (3, array([122.]))
# (5, array([302.]))
# (1, array([140.]))
# (3, array([120.]))
# (0, array([232.]))
# (2, array([91.]))
# (0, array([250.]))
# (3, array([120.]))
# (3, array([107.]))
# (3, array([116.]))
# (5, array([307.]))
# (2, array([88.]))
# (0, array([200.]))
# (2, array([86.]))
# (4, array([400.]))
# (0, array([231.]))
# (1, array([140.]))
# (1, array([151.]))
# (2, array([98.]))
# (4, array([440.]))
# (1, array([140.]))
# (1, array([141.]))
# (0, array([231.]))
# (2, array([97.5]))
# (1, array([173.]))
# (5, array([350.]))
# (1, array([145.]))
# (2, array([91.]))
# (2, array([90.]))
# (1, array([171.]))
# (3, array([121.]))

# %%
print(km.cluster_centers_)
# Out:
# [[232.76666667]
#  [149.17777778]
#  [ 89.81875   ]
#  [115.66666667]
#  [410.59090909]
#  [328.22222222]]

# %%
b = km.cluster_centers_
print(len(b))
c = np.arange(len(b)).reshape(b.shape)
print(b.shape, c)
# Out:
# 6
# (6, 1) [[0]
#  [1]
#  [2]
#  [3]
#  [4]
#  [5]]

# %%
d = np.hstack([c, b])
print(d)
# Out:
# [[  0.         232.76666667]
#  [  1.         149.17777778]
#  [  2.          89.81875   ]
#  [  3.         115.66666667]
#  [  4.         410.59090909]
#  [  5.         328.22222222]]

# %%
# plot the 3 clusters
plt.scatter(
    np.zeros(X[y_km == 0].shape), X[y_km == 0],
    s=50, c='lightgreen',
    marker='s', edgecolor='black',
    label='cluster 1'
)

plt.scatter(
    np.ones(X[y_km == 1].shape), X[y_km == 1],
    s=50, c='orange',
    marker='o', edgecolor='black',
    label='cluster 2'
)

plt.scatter(
    2*np.ones(X[y_km == 2].shape), X[y_km == 2],
    s=50, c='lightblue',
    marker='v', edgecolor='black',
    label='cluster 3'
)

# added in class
plt.scatter(
    3*np.ones(X[y_km == 3].shape), X[y_km == 3],
    s=50, c='lightblue',
    marker='v', edgecolor='black',
    label='cluster 4'
)

plt.scatter(
    4*np.ones(X[y_km == 4].shape), X[y_km == 4],
    s=50, c='red',
    marker='v', edgecolor='black',
    label='cluster 5'
)

plt.scatter(
    5*np.ones(X[y_km == 5].shape), X[y_km == 5],
    s=50, c='lightblue',
    marker='v', edgecolor='black',
    label='cluster 6'
)

## end class
# plot the centroids
plt.scatter(
    d[:, 0], d[:, 1],
    s=250, marker='*',
    c='red', edgecolor='black',
    label='centroids'
)
plt.legend(scatterpoints=1)
plt.grid()

plt.show()

# %%
"""
We are creating a list that will hold the 
intertia_ = Sum of squared distances of samples to their closest cluster center.

We are then plotting interia_ for different k values.
"""

X = X.reshape(-1,1)
print(X.shape)
# k means determine k
distortions = []
K = range(2,20)
for k in K:
    kmeanModel = KMeans(n_clusters=k).fit(X)
    distortions.append(kmeanModel.inertia_)

# Plot the elbow
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()
# Out:
# (318, 1)

# %%
"""
From the above plot, we can conclude that k=3 works better. 
"""

y_predict = km.fit_predict(x_test)

# %%
print (y_predict[0:10])
# Out:
# [4 2 4 4 3 1 4 4 3 1]

# %%
km = KMeans(
    n_clusters=3,  init='random',
    n_init=10, max_iter=300, 
    tol=1e-04, random_state=0
)
X = np.array(auto_disp)
y_km = km.fit_predict(X.reshape(-1, 1))

# %%
for i in zip(y_km, X):
    print(i)
# Out:
# (0, 307.0)
# (0, 350.0)
# (0, 318.0)
# (0, 304.0)
# (0, 302.0)
# (0, 429.0)
# (0, 454.0)
# (0, 440.0)
# (0, 455.0)
# (0, 390.0)
# (0, 383.0)
# (0, 340.0)
# (0, 400.0)
# (0, 455.0)
# (1, 113.0)
# (2, 198.0)
# (2, 199.0)
# (2, 200.0)
# (1, 97.0)
# (1, 97.0)
# (1, 110.0)
# (1, 107.0)
# (1, 104.0)
# (1, 121.0)
# (2, 199.0)
# (0, 360.0)
# (0, 307.0)
# (0, 318.0)
# (0, 304.0)
# (1, 97.0)
# (1, 140.0)
# (1, 113.0)
# (1, 98.0)
# (2, 232.0)
# (2, 225.0)
# (2, 250.0)
# (2, 250.0)
# (2, 232.0)
# (0, 350.0)
# (0, 400.0)
# (0, 351.0)
# (0, 318.0)
# (0, 383.0)
# (0, 400.0)
# (0, 400.0)
# (2, 258.0)
# (1, 140.0)
# (2, 250.0)
# (2, 250.0)
# (1, 122.0)
# (1, 116.0)
# (1, 79.0)
# (1, 88.0)
# (1, 71.0)
# (1, 72.0)
# (1, 97.0)
# (1, 91.0)
# (1, 113.0)
# (1, 97.5)
# (1, 97.0)
# (1, 140.0)
# (1, 122.0)
# (0, 350.0)
# (0, 400.0)
# (0, 318.0)
# (0, 351.0)
# (0, 304.0)
# (0, 429.0)
# (0, 350.0)
# (0, 350.0)
# (0, 400.0)
# (1, 70.0)
# (0, 304.0)
# (0, 307.0)
# (0, 302.0)
# (0, 318.0)
# (1, 121.0)
# (1, 121.0)
# (1, 120.0)
# (1, 96.0)
# (1, 122.0)
# (1, 97.0)
# (1, 120.0)
# (1, 98.0)
# (1, 97.0)
# (0, 350.0)
# (0, 304.0)
# (0, 350.0)
# (0, 302.0)
# (0, 318.0)
# (0, 429.0)
# (0, 400.0)
# (0, 351.0)
# (0, 318.0)
# (0, 440.0)
# (0, 455.0)
# (0, 360.0)
# (2, 225.0)
# (2, 250.0)
# (2, 232.0)
# (2, 250.0)
# (2, 198.0)
# (1, 97.0)
# (0, 400.0)
# (0, 400.0)
# (0, 360.0)
# (0, 350.0)
# (2, 232.0)
# (1, 97.0)
# (1, 140.0)
# (1, 108.0)
# (1, 70.0)
# (1, 122.0)
# (1, 155.0)
# (1, 98.0)
# (0, 350.0)
# (0, 400.0)
# (1, 68.0)
# (1, 116.0)
# (1, 114.0)
# (1, 121.0)
# (0, 318.0)
# (1, 121.0)
# (1, 156.0)
# (0, 350.0)
# (2, 198.0)
# (2, 200.0)
# (2, 232.0)
# (2, 250.0)
# (1, 79.0)
# (1, 122.0)
# (1, 71.0)
# (1, 140.0)
# (2, 250.0)
# (2, 258.0)
# (2, 225.0)
# (0, 302.0)
# (0, 350.0)
# (0, 318.0)
# (0, 302.0)
# (0, 304.0)
# (1, 98.0)
# (1, 79.0)
# (1, 97.0)
# (1, 76.0)
# (1, 83.0)
# (1, 90.0)
# (1, 90.0)
# (1, 116.0)
# (1, 120.0)
# (1, 108.0)
# (1, 79.0)
# (2, 225.0)
# (2, 250.0)
# (2, 250.0)
# (2, 250.0)
# (0, 400.0)
# (0, 350.0)
# (0, 318.0)
# (0, 351.0)
# (2, 231.0)
# (2, 250.0)
# (2, 258.0)
# (2, 225.0)
# (2, 231.0)
# (2, 262.0)
# (0, 302.0)
# (1, 97.0)
# (1, 140.0)
# (2, 232.0)
# (1, 140.0)
# (1, 134.0)
# (1, 90.0)
# (1, 119.0)
# (2, 171.0)
# (1, 90.0)
# (2, 232.0)
# (1, 115.0)
# (1, 120.0)
# (1, 121.0)
# (1, 121.0)
# (1, 91.0)
# (1, 107.0)
# (1, 116.0)
# (1, 140.0)
# (1, 98.0)
# (1, 101.0)
# (0, 305.0)
# (0, 318.0)
# (0, 304.0)
# (0, 351.0)
# (2, 225.0)
# (2, 250.0)
# (2, 200.0)
# (2, 232.0)
# (1, 85.0)
# (1, 98.0)
# (1, 90.0)
# (1, 91.0)
# (2, 225.0)
# (2, 250.0)
# (2, 250.0)
# (2, 258.0)
# (1, 97.0)
# (1, 85.0)
# (1, 97.0)
# (1, 140.0)
# (1, 130.0)
# (0, 318.0)
# (1, 120.0)
# (1, 156.0)
# (1, 168.0)
# (0, 350.0)
# (0, 350.0)
# (0, 302.0)
# (0, 318.0)
# (1, 98.0)
# (1, 111.0)
# (1, 79.0)
# (1, 122.0)
# (1, 85.0)
# (0, 305.0)
# (2, 260.0)
# (0, 318.0)
# (0, 302.0)
# (2, 250.0)
# (2, 231.0)
# (2, 225.0)
# (2, 250.0)
# (0, 400.0)
# (0, 350.0)
# (0, 400.0)
# (0, 351.0)
# (1, 97.0)
# (1, 151.0)
# (1, 97.0)
# (1, 140.0)
# (1, 98.0)
# (1, 98.0)
# (1, 97.0)
# (1, 97.0)
# (1, 146.0)
# (1, 121.0)
# (1, 80.0)
# (1, 90.0)
# (1, 98.0)
# (1, 78.0)
# (1, 85.0)
# (1, 91.0)
# (2, 260.0)
# (0, 318.0)
# (0, 302.0)
# (2, 231.0)
# (2, 200.0)
# (2, 200.0)
# (1, 140.0)
# (2, 225.0)
# (2, 232.0)
# (2, 231.0)
# (2, 200.0)
# (2, 225.0)
# (2, 258.0)
# (0, 305.0)
# (2, 231.0)
# (0, 302.0)
# (0, 318.0)
# (1, 98.0)
# (1, 134.0)
# (1, 119.0)
# (1, 105.0)
# (1, 134.0)
# (1, 156.0)
# (1, 151.0)
# (1, 119.0)
# (1, 131.0)
# (1, 163.0)
# (1, 121.0)
# (1, 163.0)
# (1, 89.0)
# (1, 98.0)
# (2, 231.0)
# (2, 200.0)
# (1, 140.0)
# (2, 232.0)
# (2, 225.0)
# (0, 305.0)
# (0, 302.0)
# (0, 351.0)
# (0, 318.0)
# (0, 350.0)
# (0, 351.0)
# (2, 267.0)
# (0, 360.0)
# (1, 89.0)
# (1, 86.0)
# (1, 98.0)
# (1, 121.0)
# (2, 183.0)
# (0, 350.0)
# (1, 141.0)
# (2, 260.0)
# (1, 105.0)
# (1, 105.0)
# (1, 85.0)
# (1, 91.0)
# (1, 151.0)
# (2, 173.0)
# (2, 173.0)
# (1, 151.0)
# (1, 98.0)
# (1, 89.0)
# (1, 98.0)
# (1, 86.0)
# (1, 151.0)
# (1, 140.0)
# (1, 151.0)
# (2, 225.0)
# (1, 97.0)
# (1, 134.0)
# (1, 120.0)
# (1, 119.0)
# (1, 108.0)
# (1, 86.0)
# (1, 156.0)
# (1, 85.0)
# (1, 90.0)
# (1, 90.0)
# (1, 121.0)
# (1, 146.0)
# (1, 91.0)
# (1, 85.0)
# (1, 97.0)
# (1, 89.0)
# (1, 168.0)
# (1, 70.0)
# (1, 122.0)
# (1, 140.0)
# (1, 107.0)
# (1, 135.0)
# (1, 151.0)
# (1, 156.0)
# (2, 173.0)
# (1, 135.0)
# (1, 79.0)
# (1, 86.0)
# (1, 81.0)
# (1, 97.0)
# (1, 85.0)
# (1, 89.0)
# (1, 91.0)
# (1, 105.0)
# (1, 98.0)
# (1, 98.0)
# (1, 105.0)
# (1, 100.0)
# (1, 107.0)
# (1, 108.0)
# (1, 119.0)
# (1, 120.0)
# (1, 141.0)
# (1, 145.0)
# (1, 168.0)
# (1, 146.0)
# (2, 231.0)
# (0, 350.0)
# (2, 200.0)
# (2, 225.0)
# (1, 112.0)
# (1, 112.0)
# (1, 112.0)
# (1, 112.0)
# (1, 135.0)
# (1, 151.0)
# (1, 140.0)
# (1, 151.0)
# (1, 105.0)
# (1, 91.0)
# (1, 91.0)
# (1, 105.0)
# (1, 98.0)
# (1, 120.0)
# (1, 107.0)
# (1, 108.0)
# (1, 91.0)
# (1, 91.0)
# (1, 91.0)
# (2, 181.0)
# (2, 262.0)
# (1, 156.0)
# (2, 232.0)
# (1, 144.0)
# (1, 135.0)
# (1, 151.0)
# (1, 140.0)
# (1, 97.0)
# (1, 135.0)
# (1, 120.0)
# (1, 119.0)

# %%
y_predict = km.fit_predict(x_test)
print (y_predict[0:10])
# Out:
# [2 0 2 2 1 2 2 2 1 2]
